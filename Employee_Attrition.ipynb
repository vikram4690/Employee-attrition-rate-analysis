# %% [markdown]
# # **Importing Python libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Mount google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_csv('/content/drive/My Drive/Attrition data.csv')
data.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %% [markdown]
# # Basic check

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
data.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
data.describe(include="O")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# No     3699
# Yes     711
# Name: count, dtype: int64

# %%
data['Attrition'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Attrition Percentage')
plt.show()

# %%
sns.countplot(x=data.BusinessTravel, hue=data.Attrition)
plt.title('Impact of Bussiness Travel on Attrition')
plt.show()

# %%
sns.countplot(x=data.Department, hue=data.Attrition)
plt.title('Impact of Department on Attrition')
plt.show()

# %%
sns.countplot(x=data.Attrition, hue=data.EducationField)
plt.title('Impact of Education Field on Attrition')
plt.show()

# %%
sns.countplot(x=data.Attrition, hue=data.Gender)
plt.title('Impact of Gender on Attrition')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='JobRole', hue='Attrition', data=data)
plt.xlabel('Job Role', fontsize=10)
plt.title('Impact of Job Role on Attrition')
# Out:
# Text(0.5, 1.0, 'Impact of Job Role on Attrition')

# %%
plt.figure(figsize=(12,7))
sns.histplot(x=data.Age, hue=data.Attrition)
plt.title('Impact of Age on Attrition')
plt.show()

# %%
sns.histplot(x=data.DistanceFromHome, hue=data.Attrition)
plt.title('Impact of Distance from home on Attrition')
plt.show()

# %%
sns.histplot(x=data.MonthlyIncome, hue=data.Attrition)
plt.title('Impact of Monthly Income on Attrition')
plt.show()

# %%
sns.histplot(x=data.NumCompaniesWorked, hue=data.Attrition)
plt.title('Impact of Number of Companies Worked on Attrition')
plt.show()

# %%
sns.histplot(x=data.PercentSalaryHike, hue=data.Attrition)
plt.title('Impact of Percent Salary Hike on Attrition')
plt.show()

# %%
sns.histplot(x=data.YearsAtCompany, hue=data.Attrition)
plt.title('Impact of Years at Company on Attrition')
plt.show()

# %%
sns.countplot(x=data.EnvironmentSatisfaction, hue=data.Attrition)
plt.title('Impact of Environment Satisfaction on Attrition')
plt.show()

# %%
sns.countplot(x=data.JobLevel, hue=data.Attrition)
plt.title('Impact of Job Level on Attrition')
plt.show()

# %%
sns.countplot(x=data.JobInvolvement, hue=data.Attrition)
plt.title('Impact of Job Involvement on Attrition')
plt.show()

# %%
sns.countplot(x=data.StockOptionLevel, hue=data.Attrition)
plt.title('Impact of Stock Option Level on Attrition')
plt.show()

# %%
sns.countplot(x=data.PerformanceRating, hue=data.Attrition)
plt.title("Impact of Performance Rating on Attrition")
plt.show()

# %% [markdown]
# # **DATA PREPROCESSING**

# %%
data.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
data = pd.read_csv('/content/drive/My Drive/Attrition data.csv')
data.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %% [markdown]
# # Check Duplicate

# %%
print(data.duplicated().value_counts())
data.drop_duplicates(inplace=True)
print(len(data))
# Out:
# False    4410
# Name: count, dtype: int64
# 4410

# %% [markdown]
# # Checking missing value

# %%
data.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
data['NumCompaniesWorked']= data['NumCompaniesWorked'].fillna(data['NumCompaniesWorked'].median())

# %%
data['EnvironmentSatisfaction']=data['EnvironmentSatisfaction'].fillna(data['EnvironmentSatisfaction'].median())

# %%
data['JobSatisfaction']=data['JobSatisfaction'].fillna(data['JobSatisfaction'].median())

# %%
data['WorkLifeBalance']=data['WorkLifeBalance'].fillna(data['WorkLifeBalance'].median())

# %%
data['TotalWorkingYears']=data['TotalWorkingYears'].fillna(data['TotalWorkingYears'].median())

# %%
data.isna().sum()
# Out:
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64

# %% [markdown]
# # Categorical data handling

# %%
data.Attrition=data.Attrition.replace({'Yes':1,'No':0})

# %%
data['Over18']=data['Over18'].map({'No':0,'Y':1})
data['Gender']=data['Gender'].map({'Male':0,'Female':1})

# %%
data.BusinessTravel=data.BusinessTravel.map({'Non-Travel':0,'Travel_Rarely':2,'Travel_Frequently':1})

# %%
data.Department=data.Department.map({'Research & Development':2,'Sales':1,'Human Resources':0})

# %%
data.EducationField=data.EducationField.map({'Life Sciences':0,'Medical':1,'Marketing':2,'Technical Degree':3,'Human Resources':4})

# %%
data.JobRole=data.JobRole.map({'Sales Executive':0,'Research Scientist':1,'Laboratory Technician':2,'Manufacturing Director':3,'Healthcare Representative':4,'Manager':5,'Sales Representative':6,'Research Director':7,'Human Resources':8})

# %%
data.MaritalStatus=data.MaritalStatus.map({'Single':0,'Married':1,'Divorced':2})

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
label_encoders={}
for column in encoding_cols:
    label_encoders[column]=LabelEncoder()
    data[column]=label_encoders[column].fit_transform(data[column])

# %%
data.head()
# Out:
#    EmployeeID  Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0           1   51          0               2           2                 6
# 1           2   31          1               1           1                10
# 2           3   32          0               1           1                17
# 3           4   38          0               0           1                 2
# 4           5   32          0               2           1                10
#
#    Education  EducationField  EmployeeCount  Gender  ...  TotalWorkingYears  \
# 0          2               1              1       1  ...                1.0
# 1          1               1              1       1  ...                6.0
# 2          4               4              1       0  ...                5.0
# 3          5               1              1       0  ...               13.0
# 4          1               3              1       0  ...                9.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   int64
#  3   BusinessTravel           4410 non-null   int64
#  4   Department               4410 non-null   int64
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   int64
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   int64
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   int64
#  12  MaritalStatus            4410 non-null   int64
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
data['NumCompaniesWorked']
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       3.0
# 4       4.0
#        ...
# 4405    3.0
# 4406    2.0
# 4407    0.0
# 4408    0.0
# 4409    0.0
# Name: NumCompaniesWorked, Length: 4410, dtype: float64

# %% [markdown]
# # **Machine Learning: Splitting the data into Traning and Testing Sample**

# %%
x=data.drop(["Attrition","Over18"], axis=1)
y=data["Attrition"]

# %% [markdown]
# # Balancing the target column using smote

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
sm= SMOTE()
print("unbalanced data:  ",Counter(y))
x_sm,y_sm=sm.fit_resample(x,y)
print("balanced data:  ",Counter(y_sm))
# Out:
# unbalanced data:   Counter({0: 3699, 1: 711})
# balanced data:   Counter({0: 3699, 1: 3699})

# %% [markdown]
# # Train-Test-Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_sm,y_sm,test_size=0.25,random_state=42)

# %%
data.Attrition.value_counts()
# Out:
# Attrition
# 0    3699
# 1     711
# Name: count, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Prediction

# %%
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import classification_report,accuracy_score,f1_score

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       933
#            1       0.99      0.97      0.98       917
#
#     accuracy                           0.98      1850
#    macro avg       0.98      0.98      0.98      1850
# weighted avg       0.98      0.98      0.98      1850

# %% [markdown]
# # Checking Data is fully trained or not

# %%
train_pred=dt.predict(x_train)

# %%
print(classification_report(y_train,train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2766
#            1       1.00      1.00      1.00      2782
#
#     accuracy                           1.00      5548
#    macro avg       1.00      1.00      1.00      5548
# weighted avg       1.00      1.00      1.00      5548

# %% [markdown]
# # Random Forest Technique

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_prediction=rfc.predict(x_test)

# %%
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       933
#            1       1.00      1.00      1.00       917
#
#     accuracy                           1.00      1850
#    macro avg       1.00      1.00      1.00      1850
# weighted avg       1.00      1.00      1.00      1850

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score

# %%
prediction=rfc.predict(x_test)
cnf_matrix= confusion_matrix(y_test,prediction)
print("Accuracy Score-",accuracy_score(y_test, prediction))
# Out:
# Accuracy Score- 0.9962162162162163

# %%
fig= plt. figure(figsize=(15,6))
ax1 = fig.add_subplot(1,2,1)
ax1 = sns.heatmap(pd.DataFrame(cnf_matrix), annot = True , cmap= 'Blues' , fmt = 'd')
bottom, top = ax1.get_ylim()
ax1.set_ylim(bottom + 0.5, top - 0.5)
plt.xlabel('predicted')
plt.ylabel('expected')
plt.title('Confusion Matrix')


ax2= fig. add_subplot(1,2,2)
y_pred_proba = rfc.predict_proba(x_test)[::1]
fpe, tpr, _ = roc_curve( y_test, prediction)
auc = roc_auc_score(y_test, prediction)
ax2 = plt.plot(fpe, tpr, label = "data 1, auc="+str(auc))
plt.legend(loc=4)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
